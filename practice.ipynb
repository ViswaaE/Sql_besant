# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:viswaa@localhost

# %%
# %%sql
# create database besant;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 1 rows affected.
# []

# %%
# %%sql
# use besant;
# create table student (
#     id int primary key,
#     name varchar(50),
#     age int,
#     city varchar(50)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# describe student;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 4 rows affected.
# [('id', 'int', 'NO', 'PRI', None, ''),
#  ('name', 'varchar(50)', 'YES', '', None, ''),
#  ('age', 'int', 'YES', '', None, ''),
#  ('city', 'varchar(50)', 'YES', '', None, '')]

# %%
# %%sql
# use besant;
# SELECT * FROM EMPLOYEE;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# 2 rows affected.
# [(1, 'VISWAA', 'VISWAAESWARAN@GMAIL.COM', 21, 'ACTIVE'),
#  (2, 'SATHISH', 'SATHISH@GMAIL.COM', 22, 'active')]

# %%
# %%sql
# use besant;
# SELECT * FROM EMPLOYEESS;
# ##1.Find employees whose salary is greater than 60,000.
# select * from employeess where salary > 60000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# 10 rows affected.
# 6 rows affected.
# [(1, 'Amit Kumar', 28, 'M', 'IT', 'Software Engineer', Decimal('65000.00'), 'Bengaluru', datetime.date(2020, 3, 15), 4),
#  (4, 'Pooja Singh', 29, 'F', 'IT', 'UI Designer', Decimal('72000.00'), 'Delhi', datetime.date(2020, 10, 5), 5),
#  (5, 'Vivek Reddy', 35, 'M', 'Operations', 'Manager', Decimal('90000.00'), 'Hyderabad', datetime.date(2018, 2, 12), 8),
#  (7, 'Arjun Mehta', 31, 'M', 'IT', 'Team Lead', Decimal('85000.00'), 'Chennai', datetime.date(2019, 12, 1), 7),
#  (9, 'Rohit Verma', 30, 'M', 'Finance', 'Senior Accountant', Decimal('67000.00'), 'Delhi', datetime.date(2020, 1, 25), 5),
#  (10, 'Divya Nair', 33, 'F', 'Operations', 'Supervisor', Decimal('75000.00'), 'Bengaluru', datetime.date(2019, 6, 14), 7)]

# %%
# %%sql
# ##2.Display employees whose age is less than 30.
# SELECT * FROM employeess WHERE Age < 30;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 5 rows affected.
# [(1, 'Amit Kumar', 28, 'M', 'IT', 'Software Engineer', Decimal('65000.00'), 'Bengaluru', datetime.date(2020, 3, 15), 4),
#  (2, 'Riya Sharma', 26, 'F', 'HR', 'HR Executive', Decimal('48000.00'), 'Mumbai', datetime.date(2021, 5, 10), 3),
#  (4, 'Pooja Singh', 29, 'F', 'IT', 'UI Designer', Decimal('72000.00'), 'Delhi', datetime.date(2020, 10, 5), 5),
#  (6, 'Sneha Gupta', 27, 'F', 'Marketing', 'Marketing Analyst', Decimal('55000.00'), 'Pune', datetime.date(2021, 9, 17), 3),
#  (8, 'Neha Joshi', 24, 'F', 'HR', 'Recruiter', Decimal('42000.00'), 'Kolkata', datetime.date(2022, 4, 10), 2)]

# %%
# %%sql
# ## 3.Find employees who have exactly 5 years of experience.
# SELECT * FROM employeess WHERE Experience = 5;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 2 rows affected.
# [(4, 'Pooja Singh', 29, 'F', 'IT', 'UI Designer', Decimal('72000.00'), 'Delhi', datetime.date(2020, 10, 5), 5),
#  (9, 'Rohit Verma', 30, 'M', 'Finance', 'Senior Accountant', Decimal('67000.00'), 'Delhi', datetime.date(2020, 1, 25), 5)]

# %%
# %%sql
# SELECT * FROM employeess WHERE Join_Date < '2020-01-01';
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 4 rows affected.
# [(3, 'Karan Patel', 32, 'M', 'Finance', 'Accountant', Decimal('58000.00'), 'Ahmedabad', datetime.date(2019, 8, 20), 6),
#  (5, 'Vivek Reddy', 35, 'M', 'Operations', 'Manager', Decimal('90000.00'), 'Hyderabad', datetime.date(2018, 2, 12), 8),
#  (7, 'Arjun Mehta', 31, 'M', 'IT', 'Team Lead', Decimal('85000.00'), 'Chennai', datetime.date(2019, 12, 1), 7),
#  (10, 'Divya Nair', 33, 'F', 'Operations', 'Supervisor', Decimal('75000.00'), 'Bengaluru', datetime.date(2019, 6, 14), 7)]

# %%
# %%sql
# SELECT * FROM employeess WHERE Salary <> 55000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 9 rows affected.
# [(1, 'Amit Kumar', 28, 'M', 'IT', 'Software Engineer', Decimal('65000.00'), 'Bengaluru', datetime.date(2020, 3, 15), 4),
#  (2, 'Riya Sharma', 26, 'F', 'HR', 'HR Executive', Decimal('48000.00'), 'Mumbai', datetime.date(2021, 5, 10), 3),
#  (3, 'Karan Patel', 32, 'M', 'Finance', 'Accountant', Decimal('58000.00'), 'Ahmedabad', datetime.date(2019, 8, 20), 6),
#  (4, 'Pooja Singh', 29, 'F', 'IT', 'UI Designer', Decimal('72000.00'), 'Delhi', datetime.date(2020, 10, 5), 5),
#  (5, 'Vivek Reddy', 35, 'M', 'Operations', 'Manager', Decimal('90000.00'), 'Hyderabad', datetime.date(2018, 2, 12), 8),
#  (7, 'Arjun Mehta', 31, 'M', 'IT', 'Team Lead', Decimal('85000.00'), 'Chennai', datetime.date(2019, 12, 1), 7),
#  (8, 'Neha Joshi', 24, 'F', 'HR', 'Recruiter', Decimal('42000.00'), 'Kolkata', datetime.date(2022, 4, 10), 2),
# ...

# %%
# %%sql
# SELECT * FROM EMPLOYEES WHERE AGE BETWEEN 25 AND 30;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 28 rows affected.
# [(1, 'Aarav Mehta', 28, 'M', 'IT', 'Developer', 60000, 'Bengaluru', datetime.date(2020, 5, 12), 3),
#  (3, 'Ravi Kumar', 26, 'M', 'Finance', 'Analyst', 52000, 'Delhi', datetime.date(2021, 2, 15), 2),
#  (4, 'Sneha Rao', 30, 'F', 'IT', 'Tester', 55000, 'Hyderabad', datetime.date(2019, 7, 1), 4),
#  (6, 'Anjali Verma', 27, 'F', 'Marketing', 'Executive', 48000, 'Pune', datetime.date(2021, 5, 17), 2),
#  (8, 'Divya Patel', 29, 'F', 'Finance', 'Accountant', 58000, 'Ahmedabad', datetime.date(2019, 6, 25), 4),
#  (11, 'Sahil Jain', 25, 'M', 'IT', 'Developer', 50000, 'Chandigarh', datetime.date(2022, 1, 10), 1),
#  (12, 'Meena Das', 28, 'F', 'Marketing', 'Analyst', 49000, 'Kolkata', datetime.date(2020, 11, 18), 3),
#  (14, 'Priya Reddy', 29, 'F', 'Sales', 'Executive', 47000, 'Hyderabad', datetime.date(2021, 9, 22), 2),
#  (16, 'Aditi Joshi', 27, 'F', 'Finance', 'Clerk', 42000, 'Mumbai', datetime.date(2022, 4, 11), 1),
# ...

# %%
# %%sql
# SELECT * FROM EMPLOYEES WHERE HIRE_DATE BETWEEN '2018-01-01' AND '2020-12-31';
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 20 rows affected.
# [(1, 'Aarav Mehta', 28, 'M', 'IT', 'Developer', 60000, 'Bengaluru', datetime.date(2020, 5, 12), 3),
#  (2, 'Neha Sharma', 32, 'F', 'HR', 'Manager', 75000, 'Mumbai', datetime.date(2018, 3, 10), 6),
#  (4, 'Sneha Rao', 30, 'F', 'IT', 'Tester', 55000, 'Hyderabad', datetime.date(2019, 7, 1), 4),
#  (8, 'Divya Patel', 29, 'F', 'Finance', 'Accountant', 58000, 'Ahmedabad', datetime.date(2019, 6, 25), 4),
#  (9, 'Karan Gupta', 31, 'M', 'IT', 'Developer', 61000, 'Delhi', datetime.date(2018, 1, 19), 5),
#  (12, 'Meena Das', 28, 'F', 'Marketing', 'Analyst', 49000, 'Kolkata', datetime.date(2020, 11, 18), 3),
#  (17, 'Nikhil Das', 31, 'M', 'Marketing', 'Manager', 72000, 'Delhi', datetime.date(2018, 2, 12), 5),
#  (18, 'Riya Kapoor', 30, 'F', 'HR', 'Executive', 56000, 'Chennai', datetime.date(2019, 12, 19), 4),
#  (19, 'Arun Bhat', 29, 'M', 'IT', 'Tester', 53000, 'Kochi', datetime.date(2020, 8, 8), 3),
# ...

# %%
# %%SQL
# SELECT * FROM EMPLOYEES WHERE AGE BETWEEN 30 AND 40 AND DEPARTMENT = 'Sales';
# Out:
# UsageError: Cell magic `%%SQL` not found.
